# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import emcee
import corner
from scipy.integrate import quad
import sys
sys.path.insert(0, ".")
import cloud_mcmc
plt.rcParams.update({'font.size': 18})
plt.rcParams.update({'font.family': 'serif'})
plt.rcParams.update({'mathtext.default':'regular'})
plt.rcParams.update({'mathtext.fontset':'stixsans'})
plt.rcParams.update({'axes.linewidth': 1.5})
plt.rcParams.update({'xtick.direction':'in'})
plt.rcParams.update({'xtick.major.size': 5})
plt.rcParams.update({'xtick.major.width': 1.25 })
plt.rcParams.update({'xtick.minor.size': 2.5})
plt.rcParams.update({'xtick.minor.width': 1.25 })
plt.rcParams.update({'ytick.direction':'in'})
plt.rcParams.update({'ytick.major.size': 5})
plt.rcParams.update({'ytick.major.width': 1.25 })
plt.rcParams.update({'ytick.minor.size': 2.5})
plt.rcParams.update({'ytick.minor.width': 1.25 })

# %%
os.chdir(os.path.dirname(__file__))

res512, res1024, res2048 = np.load("../data/masses.npy", allow_pickle=True)

# initial guesses for broken power law
a1 = -0.5
a2 = 1
mpeak = 40
delta = 1

xmin = 0.1

colors = ["thistle", "lavender", "lightsteelblue"]
fcolors = ["midnightblue", "lightslategray", "steelblue"]

# %%
sampler, bins2048, center_mass2048, masses12048, n2048, fm2048 = cloud_mcmc.cloud_mcmc(res2048, 2048, run_mcmc=True,
                                                                                       color=colors[-1], 
                                                                                       fcolor=fcolors[-1])
# Out:
# Running burn-in...
# Running production...

# %%
cloud_mcmc.plotter(sampler, center_mass2048, n2048, colors[-1], fcolors[-1], bins2048, 0.1, 2048)

# %%
theta01024 = ((-5, -0.01), (0.01, 10), (0.1, 5))
sampler1024, bins1024, center_mass1024, masses11024, n1024, fm1024 = cloud_mcmc.cloud_mcmc(res1024, 1024, 
                                                                                           run_mcmc=True, 
                                                                                           color=colors[1], 
                                                                                           fcolor=fcolors[1],
                                                                                           xmin=1, 
                                                                                           theta_bounds=theta01024)
# Out:
# Running burn-in...
# /opt/anaconda3/lib/python3.8/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# Running production...

# %%
thetab512 = ((300, 1000), (-5, -0.01), (0.01, 5), (0.01, 5))
theta0512 = (500, -0.5, 1, 2)
sampler512, bins512, center_mass512, masses1512, n512, fm512 = cloud_mcmc.cloud_mcmc(res512, 512, run_mcmc=True, 
                                                                                     color=colors[-1], 
                                                                                     fcolor=fcolors[0],
                                                                                     xmin=1, theta_bounds=thetab512,
                                                                                     theta0=thet0512)
# Out:
# Running burn-in...
# Running production...

# %%
def mcmc_corner(sampler, res, setprange=False, prange=None):
    if not prange:
        samples = sampler.flatchain
        mpeaks = []
        a1s = []
        a2s = []
        deltas = []
        for theta in samples:
            mpeaks.append(theta[0])
            a1s.append(theta[1])
            a2s.append(theta[2])
            deltas.append(theta[3])
        labels = ['mpeak', 'a1', 'a2', 'delta']
        prange = ((np.amin(mpeaks), np.amax(mpeaks)), (np.amin(a1s), np.amax(a1s)),
                  (np.amin(a2s), np.amax(a2s)), (np.amin(deltas), np.amax(deltas)))
                                                               

    theta_max  = samples[np.argmax(sampler.flatlnprobability[100:])]
    mmax = theta_max[0]
    a1max = theta_max[1]
    a2max = theta_max[2]
    deltamax = theta_max[3]

    fig = corner.corner(samples, labels=labels, show_titles=True, truths=[mmax, a1max, a2max, deltamax],
                        plot_datapoints=True, fontize=12, levels=(0.68,.95), quantiles=[0.16, 0.5, 0.84], bins=40,
                        range=prange)

    plt.rcParams.update({'font.size': 14})
    plt.savefig(f"../figures/corner_mcmc_{res}.pdf", transparent=False)
    
mcmc_corner(sampler, 2048)
mcmc_corner(sampler1024, 1024)
mcmc_corner(sampler512, 512)

# %%
def cell_vol_kpc(res):
    return (10.0 / float(res)) ** 3

def model(mass, theta):
    """Broken power law model with 4 free parameters used to model the
    behavior of the cloud mass probability distribution.
    """
    mpeak, a1, a2, delta = theta
    return (mass / mpeak) ** (-a1) * (0.5 * (1 + (mass / mpeak) ** (1 / delta))) ** ((a1 - a2) * delta)

def best_fit_plotter(sampler, n, bins, center_mass, xmin, color, fcolor, res):

    nbins = 100

    data_norm = n / np.sum(n)
    samples = sampler.flatchain
    theta_max = samples[np.argmax(sampler.flatlnprobability)]

    # bin width in solar masses
    dM = (10 ** bins[1:] - 10 ** bins[:-1])

    pM = model(center_mass, theta_max)
    A = quad(model, xmin, 10 ** 4, args=theta_max)[0]
    expectation_value = pM * np.sum(n) * dM / A

    fig = plt.figure(figsize=(10, 8))
    plt.loglog(center_mass, expectation_value, c=fcolor, zorder=0, label=f"R={res} Best-fit Model", linewidth=4)
    plt.loglog(center_mass, n, color="k", linewidth=5)
    plt.loglog(center_mass, n, label=f"$R={res}$ Data", color=color, linewidth=3)
    plt.legend()
    plt.xlabel("Mass$~[M_\odot]$")
    plt.ylabel("N")
    plt.savefig(r"best_fit{res}.pdf")
    plt.show()
    
best_fit_plotter(sampler, n2048, bins2048, center_mass2048, 0.1, colors[-1], fcolors[-1], 2048)
best_fit_plotter(sampler1024, n1024, bins1024, center_mass1024, 0.1, colors[1], fcolors[1], 1024)
best_fit_plotter(sampler512, n512, bins512, center_mass512, 0.1, colors[0], fcolors[0], 512)

# %%
# smoothly broken power law 1D fitting
# https://docs.astropy.org/en/stable/api/astropy.modeling.powerlaws.SmoothlyBrokenPowerLaw1D.html

# %%
def init_plotter(fm, n, bins, center_mass, xmin, color, fcolor, res):

    nbins = 100

    # bin width in solar masses
    
    fig = plt.figure(figsize=(10, 8))
    plt.plot(center_mass, n, label=f"$R={res}$", color=color, linewidth=3)
    plt.loglog(center_mass, n, color="k", linewidth=5, zorder=0)
    plt.plot(center_mass, fm, color=fcolor)
    plt.xscale("log")
    plt.yscale("log")
    plt.legend()
    plt.xlabel("Mass$~[M_\odot]$")
    plt.ylabel("N")
    plt.savefig(f"init{res}.pdf")
    plt.show()
    

init_plotter(fm2048, n2048, bins2048, center_mass2048, 0.1, colors[-1], fcolors[-1], 2048)
init_plotter(fm1024, n1024, bins1024, center_mass1024, 0.1, colors[1], fcolors[1], 1024)
init_plotter(fm512, n512, bins512, center_mass512, 0.1, colors[0], fcolors[0], 512)

# %%
# plot walker paths
plt.figure(figsize=(10, 5))
for i in np.arange(0, 20, 3):
    plt.plot(sampler512.chain[i,:,0], alpha=0.37)
    plt.ylabel(r"$m_{peak}$")

plt.figure(figsize=(10, 5))
for i in np.arange(0, 20, 3):
    plt.plot(sampler512.chain[i,:,1], alpha=0.37)
    plt.ylabel(r"$a_1$")
    
plt.figure(figsize=(10, 5))
for i in np.arange(0, 20, 3):
    plt.plot(sampler512.chain[i,:,2], alpha=0.37)
    plt.ylabel(r"$a_2$")

plt.figure(figsize=(10, 5))
for i in np.arange(0, 20, 3):
    plt.plot(sampler512.chain[i,:,3], alpha=0.37)
    plt.ylabel(r"$\Delta$")
